# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\automobile_data.csv')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3                 ?  alfa-romero       gas        std          two  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# a. Convert all the ‘?’ values to NaN. Clean the data as per further requirements.
df.replace('?',np.nan,inplace = True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3               NaN  alfa-romero       gas        std  \
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
df.rename(columns= {'normalized-losses':'loss'},inplace = True)

# %%
df.rename(columns= {'make':'company'} ,inplace = True)

# %%
# b Which company manufactured the most expensive car and at what price?
df1 = df.sort_values(by = ['price'],ascending = False)
x12 = df1[['company', 'price']][0:5]
x12
# Out:
#         company price
# 188  volkswagen  9995
# 169      toyota  9989
# 175      toyota  9988
# 190  volkswagen  9980
# 143      subaru  9960

# %%
# c. Calculate the maximum horsepower for each company.
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers[['company','horsepower']].max()
priceDf['horsepower']
# Out:
# company
# alfa-romero      154
# audi             160
# bmw              182
# chevrolet         70
# dodge             88
# honda             86
# isuzu             90
# jaguar           262
# mazda             84
# mercedes-benz    184
# mercury          175
# mitsubishi        88
# nissan            97
# peugot            97
# plymouth          88
# porsche          288
# renault          NaN
# saab             160
# subaru            94
# toyota            92
# volkswagen        90
# volvo            162
# Name: horsepower, dtype: object

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(10,5)})
sns.countplot(x=priceDf.horsepower)
plt.show()

# %%
df[df.company=='renault']
# Out:
#      symboling loss  company fuel-type aspiration num-of-doors body-style
# 130          0  NaN  renault       gas        std         four      wagon  \
# 131          2  NaN  renault       gas        std          two  hatchback
#
#     drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system
# 130          fwd           front        96.1  ...          132         mpfi  \
# 131          fwd           front        96.1  ...          132         mpfi
#
#      bore  stroke compression-ratio horsepower  peak-rpm city-mpg highway-mpg
# 130  3.46     3.9               8.7        NaN       NaN       23          31  \
# 131  3.46     3.9               8.7        NaN       NaN       23          31
#
#     price
# 130  9295
# 131  9895
#
# [2 rows x 26 columns]

# %%
# d. What is the total count of cars manufactured by each company?
df3 = df['company'].value_counts(ascending=False)
df3
sns.set(rc = {'figure.figsize':(25,5)})
sns.countplot(x=df.company)
plt.show()

# %%
# f. Sort the data frame according to car and price combined.
df1 = df.sort_values(by = ['price'],ascending = True)
df1[['company', 'price']]
# Out:
#         company  price
# 147      subaru  10198
# 62        mazda  10245
# 40        honda  10295
# 42        honda  10345
# 61        mazda  10595
# ..          ...    ...
# 188  volkswagen   9995
# 9          audi    NaN
# 44        isuzu    NaN
# 45        isuzu    NaN
# 129     porsche    NaN
#
# [205 rows x 2 columns]

# %%
# G. Create a new column which stores the number of doors in a car as integers.

# %%
# def door(value):
#     if value=='two':
#         value = 2
#         return int(value)
#     elif value == 'four':
#         value = 4
#         return int(value)
#     else:
#         return int(0)
    
df['doors'] = df['num-of-doors'].apply(lambda a: {'two':2,'four':4,np.nan:'0'}[a])
df
# Out:
#      symboling loss      company fuel-type aspiration num-of-doors
# 0            3  NaN  alfa-romero       gas        std          two  \
# 1            3  NaN  alfa-romero       gas        std          two
# 2            1  NaN  alfa-romero       gas        std          two
# 3            2  164         audi       gas        std         four
# 4            2  164         audi       gas        std         four
# ..         ...  ...          ...       ...        ...          ...
# 200         -1   95        volvo       gas        std         four
# 201         -1   95        volvo       gas      turbo         four
# 202         -1   95        volvo       gas        std         four
# 203         -1   95        volvo    diesel      turbo         four
# 204         -1   95        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  ...  fuel-system
# 0    convertible          rwd           front        88.6  ...         mpfi  \
# ...

# %%
df['num-of-doors'].unique()
# Out:
# array(['two', 'four', nan], dtype=object)

# %%
# Based on new regulations, companies decided to change the prices of the car. The
# new update price is calculated as - if the engine is in front, the price will be the same
# else if the engine is in the rear, the price will be doubled. Add a new column with the
# # updated prices.

# %%
# def price1(value, value1):
#     if value=='front':
#         return value1
#     elif value == 'rear':
#         value1 = value1*2
#         return (value1)
#     else:
#         return (0)
    
# df['new price'] = df['engine-location','price'].apply(price1)
# df

# %%
# j. Save the first and last 15 records of the dataframe in a separate Excel sheet.
df5 = df.head(16)
df6 = df.tail(16)

# %%
df5.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\automobile_data_new.csv')

# %%
df6.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\automobile_data_new.csv')

# %%
# i. contatinate

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845,
171995, 135925, 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995,
23600, 61500, 58900]}
n1 = pd.DataFrame(GermanCars)
n2 = pd.DataFrame(japaneseCars)

# %%
n23 = pd.concat([n1,n2],axis=1)     # isme 2 se jada aa skta like [n2,n3,n1] here axis= 0 
n23
# Out:
#     Company   Price      Company  Price
# 0      Ford   23845       Toyota  29995
# 1  Mercedes  171995        Honda  23600
# 2       BMV  135925       Nissan  61500
# 3      Audi   71400  Mitsubishi   58900

# %%
df.head()
# Out:
#    symboling loss      company fuel-type aspiration num-of-doors   body-style
# 0          3  NaN  alfa-romero       gas        std          two  convertible  \
# 1          3  NaN  alfa-romero       gas        std          two  convertible
# 2          1  NaN  alfa-romero       gas        std          two    hatchback
# 3          2  164         audi       gas        std         four        sedan
# 4          2  164         audi       gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base  ...  fuel-system  bore  stroke
# 0          rwd           front        88.6  ...         mpfi  3.47    2.68  \
# 1          rwd           front        88.6  ...         mpfi  3.47    2.68
# 2          rwd           front        94.5  ...         mpfi  2.68    3.47
# 3          fwd           front        99.8  ...         mpfi  3.19     3.4
# 4          4wd           front        99.4  ...         mpfi  3.19     3.4
#
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'loss', 'company', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'doors'],
#       dtype='object')

# %%
df['engine-size'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      130
# 1      130
# 2      152
# 3      109
# 4      136
#       ...
# 200    141
# 201    141
# 202    173
# 203    145
# 204    141
# Name: engine-size, Length: 205, dtype: int64>

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(10,5)})

# %%
sns.countplot(x=df['engine-size'].head(20))
# Out:
# <Axes: xlabel='engine-size', ylabel='count'>

# %%
x = df[['engine-size','price']]

# %%
x[0:100]
# Out:
#     engine-size  price
# 0           130  13495
# 1           130  16500
# 2           152  16500
# 3           109  13950
# 4           136  17450
# ..          ...    ...
# 95           97   7799
# 96           97   7499
# 97           97   7999
# 98           97   8249
# 99          120   8949
#
# [100 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.heatmap(priceDf['horsepower'].head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...
