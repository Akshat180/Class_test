# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Task.1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
x = df.isna()
x.sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %% [markdown]
# ### Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df[df['title']=='House of Cards']
# Out:
#      show_id     type           title director
# 1059   s1060  TV Show  House of Cards      NaN  \
#
#                                                    cast        country
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States  \
#
#           date_added  release_year rating   duration                listed_in
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers  \
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q.2) In which year the highest number of TV Shows & Movies were released? Show with Bar Graph.

# %%
df["release_year"].value_counts().plot.barh(figsize=(30,20))
plt.show()

# %% [markdown]
# ### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
x1 = df['type'].value_counts(ascending=False)
x1.plot(kind= 'bar')
# Out:
# <Axes: xlabel='type'>

# %% [markdown]
# ### Q. 4) Show all the Movies that were released in the year 2000.

# %%
y12 = df[(df.type == "Movie") & (df.release_year==2000)]
y12
# Out:
#      show_id   type                                              title
# 180     s181  Movie                 The Nutty Professor II: The Klumps  \
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# ### Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
x12 = df[(df.type == "TV Show") & (df.country == 'India')]
x12[['type','title']]
# Out:
#          type                               title
# 4     TV Show                        Kota Factory
# 39    TV Show                        Chhota Bheem
# 50    TV Show                       Dharmakshetra
# 66    TV Show       Raja Rasoi Aur Anya Kahaniyan
# 69    TV Show      Stories by Rabindranath Tagore
# ...       ...                                 ...
# 8173  TV Show                           Thackeray
# 8235  TV Show                         The Calling
# 8321  TV Show  The Golden Years with Javed Akhtar
# 8349  TV Show              The House That Made Me
# 8775  TV Show                     Yeh Meri Family
#
# [79 rows x 2 columns]

# %% [markdown]
# ### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df['director'].value_counts()[0:10]
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# ### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
x13 = df[(df.type == "Movie") & (df.country == 'United Kingdom')^(df.listed_in == 'Comedies')]
x13
# Out:
#      show_id   type                          title
# 27       s28  Movie                      Grown Ups  \
# 152     s153  Movie  Janoskians: Untold and Untrue
# 182     s183  Movie    Welcome Home Roscoe Jenkins
# 233     s234  Movie                    Count Me In
# 292     s293  Movie                        Quartet
# ...      ...    ...                            ...
# 8732   s8733  Movie                  White Chamber
# 8733   s8734  Movie                   White Island
# 8737   s8738  Movie     Why Are We Getting So Fat?
# 8744   s8745  Movie                       Williams
# 8786   s8787  Movie                   You Can Tutu
#
#                                     director
# 27                              Dennis Dugan  \
# 152                             Brett Weiner
# 182                           Malcolm D. Lee
# 233                                  Mark Lo
# 292                           Dustin Hoffman
# ...                                      ...
# ...

# %% [markdown]
# ### Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df2 = df.copy() 
df2.dropna(inplace = True)
df2['New'] = df2['cast'].apply(lambda a : str(a.split(",")) if a else np.nan)
df2['New'] = df2['New'].apply(lambda x: 'Tom Cruise' if 'Tom Cruise' in x else x)
df2[df2['New']=='Tom Cruise']
# Out:
#      show_id   type     title              director
# 341     s342  Movie  Magnolia  Paul Thomas Anderson  \
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States  \
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration
# 341   August 1, 2021          1999      R  189 min  \
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in
# 341   Dramas, Independent Movies  \
# 1254      Classic Movies, Dramas
#
#                                             description         New
# 341   Through chance, history and divine interventio...  Tom Cruise
# 1254  Motivated by money, a selfish workaholic seeki...  Tom Cruise

# %% [markdown]
# ### Q. 9) What are the different Ratings defined by Netflix ?
# ### ▪ Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?
# ### ▪ Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %% [markdown]
# ### que 9.1)

# %%
df_country = df[(df.type == "Movie") & (df.country== 'Canada') & (df.rating == 'TV-14')]
df_country
# Out:
#      show_id   type                                        title
# 157     s158  Movie                                     Level 16  \
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director
# ...

# %% [markdown]
# ### que 9.2)

# %%
y_tv = df[(df.rating == 'R') & (df.release_year>2018) & (df.type == "TV Show")]
y_tv
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df.sort_values(by=['duration'],ascending = False)
# Out:
#      show_id     type                                  title
# 1329   s1330    Movie  The Misadventures of Hedi and Cokeman  \
# 6278   s6279    Movie                               Being AP
# 952     s953    Movie                   The Whole Nine Yards
# 6141   s6142    Movie                       American Hangman
# 929     s930    Movie                Dead Again in Tombstone
# ...      ...      ...                                    ...
# 6556   s6557  TV Show                          Dance Academy
# 2945   s2946  TV Show             Cagaster of an Insect Cage
# 5541   s5542    Movie                        Louis C.K. 2017
# 5794   s5795    Movie                  Louis C.K.: Hilarious
# 5813   s5814    Movie   Louis C.K.: Live at the Comedy Store
#
#                director                                               cast
# 1329       Julien Royal  Hedi Bouchenafa, Nassim Lyes, Fred Testot, Jul...  \
# 6278      Anthony Wonke                                         Tony McCoy
# ...

# %% [markdown]
# ### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
df_tv_show = df[df['type']=='TV Show']
df_tv_show['country'].value_counts()[0:10]
# Out:
# country
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Taiwan             68
# Canada             59
# France             49
# Australia          48
# Spain              48
# Name: count, dtype: int64

# %% [markdown]
# ### Q. 12) How can we sort the dataset by Year ?

# %%
df.sort_values(by=['release_year'],ascending = True)

# %% [markdown]
# ### Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.** Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records."Country is United Kingdom".

# %%
x_13 = df[(df.listed_in == 'Dramas') & (df.type == "Movie") & (df.country== 'United Kingdom') ^ (df.type == "TV Show") &(df.listed_in == "Kids' TV")& (df.country== 'United Kingdom')]
x_13
# Out:
#      show_id     type                           title          director
# 65       s66  TV Show                    Numberblocks               NaN  \
# 780     s781  TV Show    Ben & Holly's Little Kingdom               NaN
# 874     s875  TV Show              Booba: Food Puzzle               NaN
# 1357   s1358    Movie                           Rocks      Sarah Gavron
# 2043   s2044    Movie                         Villain  Philip Barantini
# 6099   s6100    Movie  Agatha and the Truth of Murder       Terry Loane
# 6126   s6127  TV Show                     Alphablocks               NaN
# 8627   s8628    Movie             Trespass Against Us        Adam Smith
# 8685   s8686    Movie                             VS.          Ed Lilly
#
#                                                    cast         country
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom  \
# 780   Preston Nyman, Sian Taylor, Ian Puleston-Davie...  United Kingdom
# ...

# %%
x_13.duplicated().any()
# Out:
# False
